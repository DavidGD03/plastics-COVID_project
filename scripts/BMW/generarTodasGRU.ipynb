# %%
# %run -i generatePredictionsLocal.py AMB GRU 7
# Out:
# Epoch 1/200
# 2022-04-29 11:29:40.211228: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-04-29 11:29:40.211768: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# c:\Users\user\Documents\Script Residuos\generatePredictions.py:34: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   bmw_dataS=bmw_dataS.fillna(bmw_dataS.mean())
# c:\Users\user\Documents\Script Residuos\generatePredictions.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# %run -i generatePredictionsLocal.py AMB GRU 14

# %%
# %run -i generatePredictionsLocal.py AMB GRU 28

# %%
# %run -i generatePredictionsLocal.py Puducherry GRU 7

# %%
# %run -i generatePredictionsLocal.py Puducherry GRU 14

# %%
# %run -i generatePredictionsLocal.py Puducherry GRU 28

# %%
# %run -i generatePredictionsLocal.py Goa GRU 7

# %%
# %run -i generatePredictionsLocal.py Goa GRU 14

# %%
# %run -i generatePredictionsLocal.py Goa GRU 28

# %%
# %run -i generatePredictionsLocal.py Nagaland GRU 7

# %%
# %run -i generatePredictionsLocal.py Nagaland GRU 14

# %%
# %run -i generatePredictionsLocal.py Nagaland GRU 28

# %%
# %run -i generatePredictionsLocal.py Mizoram GRU 7

# %%
# %run -i generatePredictionsLocal.py Mizoram GRU 14

# %%
# %run -i generatePredictionsLocal.py Mizoram GRU 28

# %%
# %run -i generatePredictionsLocal.py Manipur GRU 7

# %%
# %run -i generatePredictionsLocal.py Manipur GRU 14

# %%
# %run -i generatePredictionsLocal.py Manipur GRU 28
